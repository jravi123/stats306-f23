# %%
# install.packages('tidyverse')
# install.packages('nycflights13')
library(tidyverse)
library(nycflights13)
options(repr.plot.width=5, repr.plot.height=4)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.2     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %% [markdown]
# # STATS 306
# ## Homework 3:  Advanced `dplyr` and tidy data
#
# For each problem, enter the R code in the cell marked "YOUR SOLUTION HERE".

# %% [markdown]
# ## Problem 1: *Flights* Data Set Revisited (3 points)
#
# In this problem, we will revisit the `flights` data set. First, run the following code, which adds a variable `day_of_week` to `flights`. This variable corresponds to the day of the week on which each flight occurs.
#
# In the second half of the semester, we will learn how to work with time and date data using the `lubridate` package. For now, we have created a new column called day_of_week using functions from lubridate

# %%
flights <- flights %>%
  mutate(day_of_week = lubridate::wday(time_hour, label = TRUE))

# %% [markdown]
# **(a)** Recall that a flight is canceled if `arr_delay = NA`. We want to investigate whether flight cancellations tend to happen more often on some days of the week, and whether the trends in flight cancellations vary across origin airports, i.e., `JFK`, `LGA` and `EWR`. Reproduce the plot below and explain your findings. *(1 point)*

# %%
### YOUR SOLUTION HERE
# Out:
# `summarise()` has grouped output by 'origin'. You can override using the
# `.groups` argument.
# plot without title

# %% [markdown]
# (b) Create a data frame called `flights_aadlua` containing flights from the carriers; `AA`, `DL`, and `UA` only. Use `flights_aadlua` for this problem.
#
# **Display a table** which contains the top 2 routes for each carrier in terms of the percentage of extremely delayed flights (out of all non-canceled flights). Here, we define *extremely delayed* as `arr_delay >= 120` (i.e., at least 2 hours).
#
# The table should contain 6 rows and 4 columns (`origin`, `dest`, `carrier`, and `pct_delays`). Also, the rows should be arranged by `carrier` (ascending) and `pct_delays` (descending), in that order. Lastly, `pct_delays` should be rounded to 2 decimal places. *(1 point)*
#
# Note: A *route* is defined as an *(origin, destination)* pair.

# %%
### YOUR SOLUTION HERE

# %% [markdown]
# **(c)** Use `flights_aadlua` for this problem.
#
# A route is called *unique* if it is served by only one carrier. How many unique routes are served by each carrier? *(1 point)*

# %%
### YOUR SOLUTION HERE

# %% [markdown]
# ## Problem 2: Religion and Income Survey Data (2 points)
#
# In this problem, we look into the `relig_income` data set, which is based on a survey by Pew Research to understand the association between religion and income. Each cell represents the number of respondents belonging to a (religion, income) pair.

# %%
relig_income %>% head(3)
# Out:
#   religion <$10k $10-20k $20-30k $30-40k $40-50k $50-75k $75-100k $100-150k
# 1 Agnostic 27    34      60      81      76      137     122      109
# 2 Atheist  12    27      37      52      35       70      73       59
# 3 Buddhist 27    21      30      34      33       58      62       39
#   >150k Don't know/refused
# 1 84    96
# 2 74    76
# 3 53    54

# %% [markdown]
# **(a)** Is this data set tidy or not? Why or why not?
#
# If not, create a data frame called `relig_income_tidy` which is a tidy version of `relig_income`. How many rows are there in `relig_income_tidy`? *(1 point)*

# %%
### YOUR ANSWER HERE

# %% [markdown]
# **(b)** **Display a table** which consists of religions with the *lowest and highest proportions* of individuals earning at most $30,000, out of individuals whose incomes are known.
#
# The table should contain 2 rows and 2 columns (`religion` and `prop`). Also, `prop` should be rounded to 2 decimal places. **Avoid hard-coding as much as possible**.
# *(1 point)*

# %%
### YOUR ANSWER HERE

# %% [markdown]
# ## Problem 3: Starwars (3 points)
# In this problem, we are going to use the `starwars` dataset to practice more about data manipulation and visualizations.

# %%
starwars %>% print
# Out:
# # A tibble: 87 × 14
#    name     height  mass hair_color skin_color eye_color birth_year sex   gender
#    <chr>     <int> <dbl> <chr>      <chr>      <chr>          <dbl> <chr> <chr>
#  1 Luke Sk…    172    77 blond      fair       blue            19   male  mascu…
#  2 C-3PO       167    75 NA         gold       yellow         112   none  mascu…
#  3 R2-D2        96    32 NA         white, bl… red             33   none  mascu…
#  4 Darth V…    202   136 none       white      yellow          41.9 male  mascu…
#  5 Leia Or…    150    49 brown      light      brown           19   fema… femin…
#  6 Owen La…    178   120 brown, gr… light      blue            52   male  mascu…
#  7 Beru Wh…    165    75 brown      light      blue            47   fema… femin…
#  8 R5-D4        97    32 NA         white, red red             NA   none  mascu…
#  9 Biggs D…    183    84 black      light      brown           24   male  mascu…
# ...

# %% [markdown]
# **(a)** Find the top 3 `species` in `starwars`, excluding `NA`. *(0.5 points)*

# %%
### YOUR SOLUTION HERE

# %% [markdown]
# **(b)** Create a data set called `starwars_filtered` that consists of only males and females with `eye_color` starting with the letter "b". *(1 point)*

# %%
### YOUR SOLUTION HERE

# %% [markdown]
# **(c)** Using the data set created in **(b)**, create a bar plot that shows the distribution of  `eye_color`, as the proportion for both males and females as shown below.
#
# Explain whether there is an association between sex and eye color.
# *(1.5 points)*

# %%
### YOUR SOLUTION HERE
# Out:
# `summarise()` has grouped output by 'sex'. You can override using the `.groups`
# argument.
# plot without title

# %% [markdown]
# ## Problem 4: Penguins (2 points)
# In this problem, we are going to use the `penguins` dataset to practice more about data manipulation and visualizations. Run the following code to load and check the head of the penguins data.

# %%
install.packages('palmerpenguins')
library(palmerpenguins)
head(penguins)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.1           18.7          181               3750
# 2 Adelie  Torgersen 39.5           17.4          186               3800
# 3 Adelie  Torgersen 40.3           18.0          195               3250
# 4 Adelie  Torgersen   NA             NA           NA                 NA
# 5 Adelie  Torgersen 36.7           19.3          193               3450
# 6 Adelie  Torgersen 39.3           20.6          190               3650
#   sex    year
# 1 male   2007
# 2 female 2007
# 3 female 2007
# 4 NA     2007
# 5 female 2007
# 6 male   2007

# %% [markdown]
# **(a)** Remove all rows with missing values from the table, and assign the resulting table to `penguins_no_na`. Then, print 5 rows with the highest values of `bill_length_mm`. *(1/2 point)*

# %%
### YOUR SOLUTION HERE

# %% [markdown]
# **(b)** Print the top 2 species in `penguins_no_na`.
#
# Using `penguins_no_na`, create a bar plot (as shown below) of the number of penguins in each island, colored by sex, for those top 2 species. *(1.5 points)*

# %%
### YOUR SOLUTION HERE
# Out:
# plot without title
