# %%
library(tidyverse)
library(stringr)
library(lubridate)
library(readxl)
options(repr.plot.width=4, repr.plot.height=3)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %% [markdown]
# # STATS 306
# ## Homework 8: Factors, Dates and times
#
# For each problem, enter the R code in the cell marked "YOUR SOLUTION HERE".

# %% [markdown]
# ## Problem 1:  Simulated Ebola Epidemic Data (5 points)
#
# In this problem, we will work on the fictional Ebola outbreak data. Upload the file `ebola_sim.xlsx` into Google Colab.
#
# **1(a)** Read in the `ebola_sim.xlsx` data and replace the missing values in admission time `time_admission` with its median value. Combine the date and time of admission as a new column `date_time_admission` and print the first 10 rows. Note the date of admission is denoted as `date_hospitalisation`.(1 point)

# %%
# YOUR SOLUTION HERE

# %% [markdown]
# **1(b)** Create a new column `period` to classify the time of admission based on hours within the interval (6,12] as morning, (12, 17] as afternoon, (17, 21] as evening, and (21, 24] or [0,6] as night. Count the number of occurrences in each group. You don't need to remove missing values. (1 point)
#
# Hint: The `time_admission` is in character type, not POSIXct. You may consider [`striptime()`](https://www.rdocumentation.org/packages/base/versions/3.6.2/topics/strptime) to convert it into the hour, minute format first.

# %%
# YOUR SOLUTION HERE

# %% [markdown]
# **1(b)** Compute the number of days from onset to hospitalisation in January, Feburary, and March. Create a plot counting the occurrences of days in each month. (1 point)
#
# Hint: [`difftime()`](https://www.rdocumentation.org/packages/base/versions/3.6.2/topics/difftime) can be used to calculate time intervals in different units. You may consider changing the types of days and month when creating the plot.
#
# The sample plot could be ![Screenshot 2023-10-27 at 7.07.20 PM.png](data:image/png;base64,...)

# %%
# YOUR SOLUTION HERE

# %% [markdown]
# **1(d)** Remove the missing values in the onset date. For the number of cases in each week of onset date, compute the difference in number of cases between the current week and the previous week. Create a line graph to show the trend of difference in each week. (2 points)
#
# Hint: Recall that in homework 4, we introduced the `lag()` function. You can treat NA value for the week before first week as 0.
#
# The final plot could be ![Screenshot 2023-10-27 at 7.23.46 PM.png](data:image/png;base64,...)

# %%
# YOUR SOLUTION HERE

# %% [markdown]
# ## Problem 2: Employee Attrition (5 points)
#
# This is a fictional data set created by IBM data scientists. Tries to uncover the factors that lead to employee attrition and explore important questions. Upload the file `HR_Analytics.csv` into Google Colab.

# %%
# read data
hr = read.csv("HR_Analytics.csv")

# %% [markdown]
# **(a)** Generate a plot showing the distribution of Employee Attrition in terms of Age and Gender. *(1 point)*

# %%
# YOUR SOLUTION HERE

# %% [markdown]
# **(b)** Convert the following factors: `Attrition`, `BusinessTravel`,`Department`,`EducationField`, `Gender`, `JobRole`, `MaritalStatus`, `Over18`, and `OverTime` into categorical type. Return the levels of these variables. *(1 point)*

# %%
# YOUR SOLUTION HERE

# %% [markdown]
# **(c)** Convert this feature into categorical variable with three levels:
#
# * "Not_Far" (DistanceFromHome <= 10)
# * "Acceptable" (10 < DistanceFromHome <= 20)
# * "Too_Far" (DistanceFromHome >20)
#
# Generate a plot show the Attrition Rate across DistanceFromHome and BusinessTravel. (2 points)
#
# Hint: We are looking at categorical to categorical relationship diagrams here.

# %%
# YOUR SOLUTION HERE

# %% [markdown]
# **(d)** Find the mean JobSatisfaction value across JobRole. Generate a dot plot and reorder the factor in terms of JobSatisfaction. What are the JobRole with highest and lowest JobSatisfaction? *(1 point)*

# %%
# YOUR SOLUTION HERE
